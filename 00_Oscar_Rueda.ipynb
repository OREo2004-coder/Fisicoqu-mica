# %% [markdown]
# <a href="https://colab.research.google.com/github/OREo2004-coder/Fisicoqu-mica/blob/main/00_Oscar_Rueda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oscar Rueda
# ## Físico-Química
# ### Cuadernillo 00: Introducción a JupyterLab

# %% [markdown]
# ## 3. Markdown + LaTeX
#
# Las ecuaciones de la Primera Ley de la termodinámica son:
#
# $$ \Delta U = q + w \qquad \Delta H = \Delta U + \Delta (PV) $$

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2 * np.pi, 100)
plt.plot(x, np.sin(x), color='blue')
plt.title("Función seno")
plt.xlabel("x (rad)")
plt.ylabel("sen(x)")
plt.grid(True)
plt.show()

# %%
import sys
sys.path.insert(0, "/content/src")
# !pip install -r /content/requirements.txt
# Out:
# Archive:  ploteador.zip
#   inflating: .gitignore
#   inflating: Makefile
#   inflating: References/Introduccion_a_la_Fisicoquimica_Termodin.pdf
#   inflating: References/Physical Chemistry 6e by Ira N. Levine.pdf
#   inflating: References/dokumen.tips_fisicoquimica-gilbert-castellan-segunda-edicionpdf.pdf
#   inflating: notebooks/.executed/00_introduccion_jupyter.ipynb
#   inflating: notebooks/.executed/01_introduccion_plotting.ipynb
#   inflating: notebooks/.executed/02_primera_ley.ipynb
#   inflating: notebooks/.executed/03_segunda_ley.ipynb
#   inflating: notebooks/.executed/04_tercera_ley.ipynb
#   inflating: notebooks/.executed/05_clausius_clapeyron.ipynb
#   inflating: notebooks/.executed/06_cinetica_quimica.ipynb
#   inflating: notebooks/.ipynb_checkpoints/00_introduccion_jupyter-checkpoint.ipynb
#   inflating: notebooks/.ipynb_checkpoints/01_introduccion_plotting-checkpoint.ipynb
#   inflating: notebooks/.ipynb_checkpoints/02_primera_ley-checkpoint.ipynb
# ...

# %%
from utils.constantes import R
from termodinamica.primera_ley import energia_interna_gas_ideal

print(f"R = {R:.6f} J/(mol·K)")
print(f"ΔU (2 mol, Cv=12.5, ΔT=10 K) = {energia_interna_gas_ideal(2, 12.5, 300, 310):.1f} J")
# Out:
# R = 8.314463 J/(mol·K)
# ΔU (2 mol, Cv=12.5, ΔT=10 K) = 250.0 J

# %%
# !jupyter nbconvert --to html "/content/00_Oscar_Rueda.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/00_Oscar_Rueda.ipynb to html
# [NbConvertApp] ERROR | Notebook JSON is invalid: Additional properties are not allowed ('errorDetails' was unexpected)
#
# Failed validating 'additionalProperties' in error:
#
# On instance['cells'][5]['outputs'][0]:
# {'ename': 'ModuleNotFoundError',
#  'errorDetails': {'actions': [{'action': 'open_url',
#                                'actionText': 'Open Examples',
#                                'url': '/notebooks/snippets/importing_libraries.ipynb'}]},
#  'evalue': "No module named 'utils'",
#  'output_type': 'error',
#  'traceback': ['\x1b---------------------------------------------------------...',
#                '\x1bModuleNotFoundError\x1b                       '
#                'Traceback (...',
#                '\x1b/tmp/ipykernel_5959/756195663.py\x1b in '
#                '\x1b<cell line...',
#                '\x1bModuleNotFoundError\x1b: No module named '
#                "'utils'",
# ...
